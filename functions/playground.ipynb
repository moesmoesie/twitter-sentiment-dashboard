# %%
from models.keyword import Keyword
import os
from dotenv import load_dotenv
from tweets import TwitterAPI

load_dotenv()
twitter_api = TwitterAPI(os.environ["TWITTER_BEARER_TOKEN"])

# %%
keywords = [
    "#Party",
    "#Fun",
    "@Jason",
    "Hello World"
]

# %%
twitter_api.search("")
# Out:
#                                             full_text  retweet_count  \
# 0   De maatregelen die we nemen, zijn voor iederee...             17
# 1   Complimenten aan @ggdkennemerland voor het ade...              8
# 2   We mogen niet immuun worden voor het leed dat ...             23
# 3   Samen met @GGDGHORNL en @rivm doen we alles om...             21
# 4   Zometeen de persconferentie door @minpres en m...             11
# 5   De situatie in de zorg is zorgelijk. Vandaag h...             24
# 6   Het zetten van #oppepprikken bij 80+'ers is in...             19
# 7   Vanaf vandaag 12.00 uur geldt er een vliegverb...            116
# 8   RT @skipr: Ministerie maakt vast contract moge...              7
# 9   Twijfel je over de prik? Bel de Vaccinatie Twi...            103
# 10  Geboren in 1️⃣9️⃣3️⃣9️⃣ of eerder? \n🕚 Om 11:0...             38
# 11  Ook in de thuiszorg, gehandicaptenzorg en verp...             16
# 12  We zetten alles op alles om mensen te bereiken...             31
# 13  De situatie is zorgelijk: afgelopen 2 dagen zi...             43
# 14  Mensen blijven kiezen voor vaccinatie. Een ver...             24
#
#    result_type
# 0       recent
# 1       recent
# 2       recent
# 3       recent
# 4       recent
# 5       recent
# 6       recent
# 7       recent
# 8       recent
# 9       recent
# 10      recent
# 11      recent
# 12      recent
# 13      recent
# 14      recent

# %%
# Out:
# {'iso_language_code': 'nl', 'result_type': 'recent'}
